# %%
import nltk
nltk.download('punkt')
# import numpy as np
# import pandas as pd
# import codecs
# from nltk.corpus import stopwords
# import numpy as np
# import pandas as pd
# import re
# import csv
# import string
# from datetime import datetime
# from collections import Counter
# from nltk.tokenize import TweetTokenizer
# from nltk.tokenize import   RegexpTokenizer
# from nltk.tokenize import sent_tokenize, word_tokenize
# # --------------------------------------- #
# import pyarabic.araby as araby
# import pyarabic.number as number
# from pyarabic.araby import strip_tashkeel
# from pyarabic.araby import strip_tatweel
# from pyarabic.araby import tokenize, is_arabicrange, strip_tashkeel
# # --------------------------------------- #
# import pyarabic.arabrepr
# arepr = pyarabic.arabrepr.ArabicRepr()
# repr = arepr.repr
# from tashaphyne.stemming import ArabicLightStemmer
# import emoji


# import seaborn
# import matplotlib.pyplot as plt
! pip install nltk --user

# %matplotlib inline
# Out:
# Requirement already satisfied: nltk in c:\users\dell\appdata\roaming\python\python39\site-packages (3.5)
# Requirement already satisfied: click in c:\users\dell\appdata\roaming\python\python39\site-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in c:\users\dell\appdata\roaming\python\python39\site-packages (from nltk) (1.0.1)
# Requirement already satisfied: regex in c:\users\dell\appdata\roaming\python\python39\site-packages (from nltk) (2020.11.13)
# Requirement already satisfied: tqdm in c:\users\dell\appdata\roaming\python\python39\site-packages (from nltk) (4.56.2)
# WARNING: You are using pip version 20.2.3; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\users\dell\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-610d41271328> in <module>
#      33 get_ipython().system(' pip install nltk --user')
#      34
# ---> 35 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2334                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2335             with self.builtin_trap:
# -> 2336                 result = fn(*args, **kwargs)
#    2337             return result
#    2338
#
# <decorator-gen-102> in matplotlib(self, line)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\magics\pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py in enable_matplotlib(self, gui)
#    3501         """
#    3502         from IPython.core import pylabtools as pt
# -> 3503         gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    3504
#    3505         if gui != 'inline':
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py in find_gui_and_backend(gui, gui_select)
#     278     """
#     279
# --> 280     import matplotlib
#     281
#     282     if gui and gui != 'auto':
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# # read or import the DATA2 after sparated from the whole dataset

# %%
! pip install nltk --user

# %%
# this below is for demonstration we use data called newdata
df = pd.read_csv('Dataset1.csv', names=['id','text'])
# you can see we took only text and id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-03b9a504dbc9> in <module>
#       1 # this below is for demonstration we use data called newdata
# ----> 2 df = pd.read_csv('Dataset1.csv', names=['id','text'])
#       3 # you can see we took only text and id
#
# NameError: name 'pd' is not defined

# %%
newdata = df.reset_index()
newdata["id"] = newdata.index 
#newdata.head()
newdata.columns= newdata.columns.str.lower()
newdata.columns
# Out:
# Index(['index', 'id', 'text'], dtype='object')

# %%
# NO need for screen_name only text and id

# when aparete the datset it will show like this ( ignor the screen_name) and the rest data will be in DATA1

new = newdata[['text','id']] 
new.head()
# Out:
#                                                 text  id
# 0  @AlkahrabaCare @MoEnergy_Saudi @SeecSaudi @Sau...   0
# 1  @AL_HAALEM @MoEnergy_Saudi @SeecSaudi @Saudi_A...   1
# 2  @AlkahrabaCare @MoEnergy_Saudi @SeecSaudi @Sau...   2
# 3  RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...   3
# 4  RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...   4

# %% [markdown]
# ## this the pre-processing stage, this icludes:
#
#
# - cleaning the text statrting from punctuations, hashtags, other unnecessary things to prepare it for prediction ( ONLY RUN THEM )

# %%
arabic_punctuations = '''`÷×؛<>_()*&^%][ـ،/:"؟.,'{}~¦+|!”…“–ـ'''
english_punctuations = string.punctuation
punctuations_list = arabic_punctuations + english_punctuations
arabic_diacritics = re.compile("""
                             ّ    | # Tashdid
                             َ    | # Fatha
                             ً    | # Tanwin Fath
                             ُ    | # Damma
                             ٌ    | # Tanwin Damm
                             ِ    | # Kasra
                             ٍ    | # Tanwin Kasr
                             ْ    | # Sukun
                             ـ     # Tatwil/Kashida
                         """, re.VERBOSE)


def normalize_arabic(text):
    text = re.sub("[إأآا]", "ا", text)
    text = re.sub("ى", "ي", text)
    text = re.sub("ؤ", "ء", text)
    text = re.sub("ئ", "ء", text)
    text = re.sub("ة", "ه", text)
    text = re.sub("گ", "ك", text)
    return text

# def space(text):
#     text= re.sub(r"_", '\s+', s)
#     return text

# new1['text'].replace('_', ' ', regex=True, inplace=True)


def remove_diacritics(text):
    text = re.sub(arabic_diacritics, '', text)
    return text


def remove_punctuations(text):
    translator = str.maketrans('', '', punctuations_list)
    return text.translate(translator)


def remove_repeating_char(text):
    return re.sub(r'(.)\1+', r'\1', text)

def remove_hashtag(text):
    return text.replace("#\\p{IsAlphabetic}+", "");

# %%
def processPost(tweet):

    #Replace @username with empty string
    tweet = re.sub('@[^\s]+', ' ', tweet)
    
    #Replace RT with empty string
    tweet = re.sub('RT', ' ', tweet)
    
    #Convert www.* or https?://* to " "
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))',' ',tweet)
    
    #Replace #word with word
    tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
    
    
    #remove non-arabic
#      tweet = re.sub(r'[^ء-ي0-9]',' ',tweet)

    return tweet

# %%
new['text'].replace('[^ء-ي0-9]', ' ', regex=True, inplace=True)

new['text'].replace('_', ' ', regex=True, inplace=True)

new['text'] = new['text'].str.replace(r'\d+','')

new['text']= new['text'].apply(lambda x: remove_diacritics(x))

new['text']= new['text'].apply(lambda x: remove_repeating_char(x))

new['text']= new['text'].apply(lambda x: processPost(x))

new['text']= new['text'].apply(lambda x: remove_hashtag(x))

new['text']= new['text'].apply(lambda x: remove_punctuations(x))

new['text']= new['text'].apply(lambda x: remove_repeating_char(x))
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\series.py:4576: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
# <ipython-input-29-832ef3aa93db>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['text'] = new['text'].str.replace(r'\d+','')
# <ipython-input-29-832ef3aa93db>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['text']= new['text'].apply(lambda x: remove_diacritics(x))
# <ipython-input-29-832ef3aa93db>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['text']= new['text'].apply(lambda x: remove_repeating_char(x))
# <ipython-input-29-832ef3aa93db>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['text']= new['text'].apply(lambda x: processPost(x))
# <ipython-input-29-832ef3aa93db>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['text']= new['text'].apply(lambda x: remove_hashtag(x))
# <ipython-input-29-832ef3aa93db>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['text']= new['text'].apply(lambda x: remove_punctuations(x))
# <ipython-input-29-832ef3aa93db>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['text']= new['text'].apply(lambda x: remove_repeating_char(x))
# 0                                                اشكركم
# 1                       أخي العزيز أبوسعود تم الرد على
# 2                              تم فتح تم إغلاق مكن اعر
# 3      اختيارك لسيارة على المستوى الأخضر في بطاقة اق...
# 4      اختيارك لسيارة على المستوى الأخضر في بطاقة اق...
# 5      اختيارك لسيارة على المستوى الأخضر في بطاقة اق...
# 6      اختيارك لسيارة على المستوى الأخضر في بطاقة اق...
# 7      اختيارك لسيارة على المستوى الأخضر في بطاقة اق...
# 8      اختيارك لسيارة على المستوى الأخضر في بطاقة اق...
# 9      محطة توليد كهرباء بالطاقة الشمسية قدرتها ميقا...
# 10     السيارة ما تحتاج أكثر من ثانية لتسخين حتى في ...
# 11            سؤالي هو ميقاوات تشغل كم مكيف فريون وحدة
# 12     لتنازل لتنازل جنسية سريلانكية الديانة مسلم ال...
# 13     اختيارك لسيارة على المستوى الأخضر في بطاقة اق...
# 14               طيب ياخي كيف اعرف سيارتي مافيها الملصق
# 15     اختيارك لسيارة على المستوى الأخضر في بطاقة اق...
# 16     اختيارك لسيارة على المستوى الأخضر في بطاقة اق...
# 17     اختيارك لسيارة على المستوى الأخضر في بطاقة اق...
# 18                   وعليكم السلام الأخ الفاضل ابو سعو
# 19     السلام عليكم اخي الكريم تم الاعتراض وجاء مندو...
# 20     حياكم اله فترة مايستهلكه السخان العادي في ساع...
# 21     السخان العادي يستهلك مالا يزيد عن واط أما الف...
# 22           السخان الفوري أفضل من السخان العادي لتبقى
# 23     العلا و نيوم وبعض حديث عن الطاقة كلها أمور اج...
# 24     العلا و نيوم وبعض حديث عن الطاقة كلها أمور اج...
# 25     شكرا اذا قصرتوا الاخ قوقل ما راح يقصر يجيبها ...
# 26    العلا و نيوم وبعض حديث عن الطاقة كلها أمور اجت...
# 27     مرحب ا بك نقدر اهتمامك بالترشيد ويمكنك التواص...
# 28     نصائح وسلوكيات بسيطة تساعدك بالتوفير من استهل...
# 29     ودكم توف رون أكثر من ريال من تكاليف البنزين ل...
# 30                  السلام عليكم ايش افضل نوع سخان فوري
# 31     السيارة ما تحتاج أكثر من ثانية لتسخين حتى في ...
# 32     ثانية تختلف من مركبة لأخرى سيارتي مثلا في درج...
# 33     حتى لمبة الحرارة الزرقاء ماتطفى بعد ثانية على...
# 34     السيارة ما تحتاج أكثر من ثانية لتسخين حتى في ...
# 35                                    ياليت تشرحون اكثر
# 36     السيارة ما تحتاج أكثر من ثانية لتسخين حتى في ...
# 37                                       هل من شرح أكثر
# 38     السيارة ما تحتاج أكثر من ثانية لتسخين حتى في ...
# 39     السيارة ما تحتاج أكثر من ثانية لتسخين حتى في ...
# 40     السيارة ما تحتاج أكثر من ثانية لتسخين حتى في ...
# 41                                            شكرا لكم
# 42     السلام عليكم اريد اشتري لي جهاز كهربائي وكلها...
# 43              اقول متا ينزل البنزين ونرتاح وله شي صعب
# 44     تكفون ادعموني ب لايك او رتويت اله يرزقكم يارب...
# Name: text, dtype: object

# %%
tokens = TweetTokenizer()
new['text'] = new['text'].apply(tokens.tokenize)
# Out:
# <ipython-input-13-3ad1ae8a2869>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['text'] = new['text'].apply(tokens.tokenize)

# %% [markdown]
# ### THIS is a pre-built lexicon will be used for the arabic stop word

# %%
stop = ['إذ', 'إذا', 'إذما', 'إذن', 'أف', 'أقل', 'أكثر', 'ألا', 'إلا', 'التي', 'الذي', 'الذين', 'اللاتي', 'اللائي', 'اللتان', 'اللتيا', 'اللتين', 'اللذان', 'اللذين', 'اللواتي', 'إلى', 'إليك', 'إليكم', 'إليكما', 'إليكن', 'أم', 'أما', 'أما', 'إما', 'أن', 'إن', 'إنا', 'أنا', 'أنت', 'أنتم', 'أنتما', 'أنتن', 'إنما', 'إنه', 'أنى', 'أنى', 'آه', 'آها', 'أو', 'أولاء', 'أولئك', 'أوه', 'آي', 'أي', 'أيها', 'إي', 'أين', 'أين', 'أينما', 'إيه', 'بخ', 'بس', 'بعد', 'بعض', 'بك', 'بكم', 'بكم', 'بكما', 'بكن', 'بل', 'بلى', 'بما', 'بماذا', 'بمن', 'بنا', 'به', 'بها', 'بهم', 'بهما', 'بهن', 'بي', 'بين','و', 'بيد',
         'تلك', 'تلكم', 'تلكما', 'ته', 'تي', 'تين', 'تينك',
         'ثم', 'ثمة', 'حاشا', 'حبذا', 'حتى', 'حيث', 'حيثما',
         'حين', 'خلا', 'دون', 'ذا', 'ذات', 'ذاك', 'ذان', 'ذانك', 'ذلك',
         'ذلكم', 'ذلكما', 'ذلكن', 'ذه', 'ذو', 'ذوا', 'ذواتا',
         'ذواتي', 'ذي', 'ذين', 'ذينك', 'ريث', 'سوف', 'سوى', 'شتان', 'عدا',
         'عسى', 'عل', 'على', 'عليك', 'عليه', 'عما', 'عن', 'عند', 'غير',
         'فإذا', 'فإن', 'فلا', 'فمن', 'في', 'فيم', 'فيما', 'فيه', 'فيها',
         'قد', 'كأن', 'كأنما', 'كأي', 'كأين', 'كذا', 'كذلك', 'كل', 'كلا',
         'كلاهما', 'كلتا', 'كلما', 'كليكما', 'كليهما', 'كم', 'كم', 'كما',
         'كي', 'كيت', 'كيف', 'كيفما', 'لا', 'لاسيما', 'لدى', 'لست', 'لستم',
         'لستما', 'لستن', 'لسن', 'لسنا', 'لعل', 'لك', 'لكم', 'لكما',
         'لكن', 'لكنما', 'لكي', 'لكيلا', 'لم', 'لما', 'لن', 'لنا',
         'له', 'لها', 'لهم', 'لهما', 'لهن', 'لو', 'لولا', 'لوما',
         'لي', 'لئن', 'ليت', 'ليس', 'ليسا', 'ليست', 'ليستا', 'ليسوا', 'ما',
         'ماذا', 'متى', 'مذ', 'مع', 'مما', 'ممن', 'من', 'منه', 'منها', 'منذ',
         'مه', 'مهما', 'نحن', 'نحو', 'نعم', 'ها', 'هاتان', 'هاته', 'هاتي',
         'هاتين', 'هاك', 'هاهنا', 'هذا', 'هذان', 'هذه', 'هذي', 'هذين', 'هكذا',
         'هل', 'هلا', 'هم', 'هما', 'هن', 'هنا', 'هناك', 'هنالك', 'هو', 'هؤلاء',
         'هي', 'هيا', 'هيت', 'هيهات', 'والذي', 'والذين', 'وإذ', 'وإذا', 'وإن',
         'ولا', 'ولكن', 'ولو', 'وما', 'ومن', 'وهو', 'يا' , 'من' , 'على', 'الى','هما', 'مع', 'هذه', 'التي', 'كما ', 'ذلك ', 'لذا', 'عن', 'في','ان','كان','كانت','الى','قبل','أنه','تم'
        ,'وقال','قال','فى','وقد','قد','ولم','وذلك','ذلك','يكون','او','وهذه','وهي ','وبعد','وهذا','عندها','جدا','بأن','انه','الي']

# %%
new['text'] = [w for w in new['text'] if not w in stop]
new.head()
# Out:
# <ipython-input-11-4cdd638f4f34>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['text'] = [w for w in new['text'] if not w in stop]
#       screen_name                                    text  id
# 0         retajf8                                [بنفسجي]   0
# 1    Saud00420429                          [ياثقل, طينته]   1
# 2        ghuood67                                [الأحمر]   2
# 3          Rohy66  [لايضحكون, عليك, النفسيات, بالخزعبلات]   3
# 4  Asdasd61622655                          [سماوي, واسود]   4

# %%
y = new['text'].apply(lambda x: ' '.join(x))
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(max_features=250, min_df=5, max_df=0.7, stop_words=stop)
X = vectorizer.fit_transform(y).toarray()
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sklearn\feature_extraction\text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['وهي'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidfconverter = TfidfTransformer()
X = tfidfconverter.fit_transform(X).toarray()

# %% [markdown]
# ### we import the model we built

# %%
import pickle
# acc = 77 or 79
with open('RFModel250', 'rb') as training_model:
    taqa = pickle.load(training_model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-52cac713c133> in <module>
#       2 # acc = 77 or 79
#       3 with open('RFModel250', 'rb') as training_model:
# ----> 4     taqa = pickle.load(training_model)
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree.__cinit__()
#
# ValueError: Buffer dtype mismatch, expected 'SIZE_t' but got 'long long'

# %% [markdown]
# ### now after pre-processing we predict

# %%
new['predictions'] = taqa.predict(X)
#Or newdata['predictions'] = pd.DataFrame(Predictions) - if Length of values does not match length of index
# Out:
# <ipython-input-15-a35aa5db218b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['predictions'] = taqa.predict(X)

# %%
new.head()
# Out:
#       screen_name                                    text  id predictions
# 0         retajf8                                [بنفسجي]   0     Neutral
# 1    Saud00420429                          [ياثقل, طينته]   1     Neutral
# 2        ghuood67                                [الأحمر]   2    Positive
# 3          Rohy66  [لايضحكون, عليك, النفسيات, بالخزعبلات]   3     Neutral
# 4  Asdasd61622655                          [سماوي, واسود]   4     Neutral

# %% [markdown]
# # After finishing the sentiment we want to catogeries each tweets based on the a predifend category)

# %%
# 15
Ad = ["دعايه","لداعياتكم","الفكره", "الوقت" , "الاعلان", "اعلانكم","فكره","اعلان", "التوقيت","الاخراج","التصوير", "وقت"]

religon = ["يوفقك","رسول","حرام","حلال","موسيقى" ,"اغاني", "أغاني", "بنات","متبرجة","متبرجه","كاشفة", "كاشفه","مايجوز","استغفرالله"]

Others = []

Actor = ["تمثيل","ممثل","التمثيل","تمثيله","شخصيات", "الاداء", "اداء", "شخصيه", "يمثل","الممثل", "المثل", ""]

# %%
def setcategory(tweet):
    label="Others"
    for word in Ad:
        if word in tweet:
            label="Ad"
            
        for word in Islami:
            if word in tweet:
                label="Islami"
            
            for word in Actor:
                if word in tweet:
                    label="Actor"
            
    return label

# %%
new["category"] = new['text'].apply(lambda x: setcategory(x))
# Out:
# <ipython-input-25-9cc15df17522>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new["category"] = new['text'].apply(lambda x: setcategory(x))

# %%
# change the seeting of the  cells
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-21-614210297620>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# # Final outcome DATA2
#
# - text
# - id
# - prediction
# - category
#
# note: no need for screen_name this data is only to show you how it works

# %%
new
# Out:
#           screen_name  \
# 0     retajf8
# 1     Saud00420429
# 2     ghuood67
# 3     Rohy66
# 4     Asdasd61622655
# 5     ph_abdullah_18
# 6     hnk12hnk
# 7     hnk12hnk
# 8     dB5ByZl1q6Jz7Wj
# 9     Q6MifpnV5LRFux8
# 10    GH5338
# 11    hnk12hnk
# 12    MuhSufana
# 13    nodisa8
# 14    2274_m
# 15    iAljumah
# 16    2274_m
# 17    Nano97187337
# 18    Nano97187337
# 19    Nano97187337
# 20    Nano97187337
# 21    B_sh339
# 22    Bader_M201
# 23    khiru56
# 24    Bader_M201
# 25    Nano97187337
# 26    khiru56
# 27    l5783l
# 28    97Dodh
# 29    loloZ46669607
# 30    r_llll22
# 31    hyalhassan
# 32    rince001
# 33    hyalhassan
# 34    hyalhassan
# 35    hyalhassan
# 36    zdlln
# 37    bushraalomar
# 38    rince001
# 39    7QSYZW1
# 40    0Emyo
# 41    SARiyadh24
# 42    SARiyadh24
# 43    _0ELI5
# 44    SARiyadh24
# 45    SARiyadh24
# 46    modi_216
# 47    wNXEGhhyIarxSfw
# 48    65WZ
# 49    mtms1404
# 50    modeer_mnsbh
# 51    mwooody
# 52    mwooody
# 53    mtms1404
# 54    mtms1404
# 55    goldencode1
# 56    Saudi25468046
# 57    Izain_x
# 58    wojod_saleh
# 59    DMMSTyYWS3TfBCu
# 60    saraeeil
# 61    ___loliii
# 62    hotelairbook
# 63    Qrji12
# 64    hoda_1927
# 65    qwzx2010001
# 66    hoda_1927
# 67    x_m18h
# 68    x_m18h
# 69    albader2285
# 70    x_m18h
# 71    AAAAAA45UUU
# 72    xx_amjad11
# 73    xx_amjad11
# 74    449_ohsehunn
# 75    horrible_4
# 76    449_ohsehunn
# 77    rxnv1
# 78    horrible_4
# 79    xx_amjad11
# 80    Amool_12346
# 81    1Tmneetk
# 82    galaxy_plus
# 83    galaxy_plus
# 84    miva_7
# 85    aa19372095
# 86    mnifa16
# 87    mnifa16
# 88    mnifa16
# 89    mnifa16
# 90    mnifa16
# 91    mnifa16
# 92    mnifa16
# 93    mnifa16
# 94    mnifa16
# 95    4_lavender_
# 96    ufmradio
# 97    mokuro07
# 98    mokuro07
# 99    mnifa16
# 100   mnifa16
# 101   mnifa16
# 102   mnifa16
# 103   eimanff
# 104   eimanff
# 105   kw_t65Mustafa
# 106   aasamar
# 107   zainbalqahtani
# 108   F____35
# 109   iKhaled1985
# 110   mmm44563
# 111   alshmmri_bandar
# 112   alnaif_telecom
# 113   aa19372095
# 114   ssssioioio
# 115   Kids83965508
# 116   LNFZ1g1kUNVcZhb
# 117   Bader_M201
# 118   Bader_M201
# 119   Aida51340017
# 120   Miix8z
# 121   Bader_M201
# 122   311_wf
# 123   jamali_nawaf
# 124   TwBoKJkcXgMAfru
# 125   akhbarcom4
# 126   w288898812
# 127   akadonia
# 128   Shalmazroa
# 129   qilipr
# 130   qilipr
# 131   r_vzh
# 132   Amore1Mh
# 133   F40631846
# 134   StZoro7
# 135   Mariam14952025
# 136   hotei336
# 137   selwan88920252
# 138   idcranal
# 139   algahra2013
# 140   good96017
# 141   hotei336
# 142   MIx0Fy4OgHevt5L
# 143   hotei336
# 144   YaserAlotaibi2
# 145   DFYerb6b56AqGz1
# 146   smroon113
# 147   BbagoodD
# 148   7mood50600438
# 149   abdullh_H12
# 150   Amore1Mh
# 151   DFYerb6b56AqGz1
# 152   DFYerb6b56AqGz1
# 153   fahd1w
# 154   LOVEWHISPER11
# 155   Reem14181418141
# 156   Kids83965508
# 157   s77com
# 158   HRYimOcykoy6ZOH
# 159   Piterhok
# 160   Piterhok
# 161   seory5
# 162   ghm707_1
# 163   Piterhok
# 164   s77com
# 165   Piterhok
# 166   hershamkamal
# 167   4Ks2A
# 168   HRYimOcykoy6ZOH
# 169   dj1642
# 170   ixRoy
# 171   omar555529
# 172   LuozFBHC9sD78ap
# 173   LuozFBHC9sD78ap
# 174   eCf8erT92kJtDh2
# 175   alrayed_1616
# 176   BlueBird_110262
# 177   ksamissionun
# 178   DyPIBaTlEmbjDyQ
# 179   hershamkamal
# 180   _qzo4
# 181   Hno281
# 182   zahwn
# 183   zahwn
# 184   alrayed_1616
# 185   sayelnosir
# 186   dandonalsafa
# 187   abdulkarimalqa8
# 188   abdulkarimalqa8
# 189   xdr1187
# 190   altamimi_hassan
# 191   altamimi_hassan
# 192   as1112233
# 193   Kids83965508
# 194   kDPss1QSL64hlWi
# 195   oiigee1
# 196   alasmary_hloom
# 197   bhralhodoa
# 198   alasmary_hloom
# 199   sabahmorrah
# 200   sabahmorrah
# 201   mobarki1982
# 202   OfV6Wixy249Llt7
# 203   rahf_mahrous
# 204   bashar_soboh
# 205   moskooo7709
# 206   moskooo7709
# 207   moskooo7709
# 208   Hazza08864852
# 209   mobarki1982
# 210   ZainabBintOmar
# 211   qu5v7
# 212   Falkhiwani
# 213   d33d2
# 214   iKhaled1985
# 215   Bader_M201
# 216   Bader_M201
# 217   qu5v7
# 218   MooedShehab
# 219   ulewz8uU4FdXr8i
# 220   joojooaj1
# 221   asrar06308203
# 222   ulewz8uU4FdXr8i
# 223   joojooaj1
# 224   Bader_M201
# 225   HcDPSLpD79tunhk
# 226   _SCOOP_8
# 227   cXJ5haVRKWpJPRB
# 228   ezalkouy
# 229   IfayIf
# 230   bs8jn12345salah
# 231   ad10987
# 232   k7ZSyWJWI5m0RiK
# 233   nxy92
# 234   Alwazzanas
# 235   ll3x3i
# 236   SHMOUKHF
# 237   nxy92
# 238   malakalfahad_
# 239   5TwV2OKRJt9Jbz4
# 240   BarghashGhada
# 241   Helyyil
# 242   Farouksaad05
# 243   ili9___
# 244   MOGNHCUqmesp9VI
# 245   w10FwXL0KeHj1Rn
# 246   w10FwXL0KeHj1Rn
# 247   Ommusta21998430
# 248   eslteacheromar
# 249   althoq_alraked
# 250   althoq_alraked
# 251   8_KOZYYT
# 252   Reem_mare
# 253   ZAID_ALZAID1998
# 254   RhyeBUVyZGS4ykR
# 255   RhyeBUVyZGS4ykR
# 256   K1OujhzrUQflCpj
# 257   took16059401
# 258   fawwazalenzi
# 259   bushraalomar
# 260   amira2388
# 261   amira2388
# 262   took16059401
# 263   SultanMatar3
# 264   FreedomKingdom8
# 265   vatanth
# 266   vatanth
# 267   memsh5311
# 268   sma112012
# 269   Sst700Mohamed
# 270   K1OujhzrUQflCpj
# 271   H0_Girl
# 272   323423232
# 273   Ahmed_acm94
# 274   awe91210192
# 275   HfcHlalaeh
# 276   SSS_9I
# 277   abg_h
# 278   april8_16
# 279   RwAOBBA8tCk5P9m
# 280   Sst700Mohamed
# 281   manssor66s
# 282   abg_h
# 283   manssor66s
# 284   Ran_Mer2017
# 285   Eva_amb
# 286   Mansour_4m
# 287   abwaebdalllah11
# 288   y_xy24
# 289   demoniic0
# 290   demoniic0
# 291   y_xy24
# 292   demoniic0
# 293   y_xy24
# 294   demoniic0
# 295   y_xy24
# 296   demoniic0
# 297   dl_eman
# 298   Leon52811781
# 299   a7o6k
# 300   a7o6k
# 301   y_xy24
# 302   Om_WeMe
# 303   badr_alkhalid
# 304   badr_alkhalid
# 305   badr_alkhalid
# 306   badr_alkhalid
# 307   Om_WeMe
# 308   0EoNRjP0v5ZDzAR
# 309   nofa_2011
# 310   yallahya7bebe
# 311   joojooaj1
# 312   Eva_amb
# 313   joojooaj1
# 314   Ran_Mer2017
# 315   Wadha_060
# 316   maram29165877
# 317   omzahrani
# 318   Eva_amb
# 319   mmod1990
# 320   _lvmv_0
# 321   iti_had1
# 322   Wadha_060
# 323   omzahrani
# 324   joojooaj1
# 325   alshmmile1
# 326   Z6u2uedGP5XdZb9
# 327   m_x1c2c33
# 328   Leon52811781
# 329   3021ahotmail
# 330   omzahrani
# 331   NN0N7
# 332   googoo2277
# 333   MSalahM5
# 334   1iAbrar
# 335   Gfjl6
# 336   myttaap
# 337   Gyoum111
# 338   ___xFA
# 339   oRN5wQiyWqYkIum
# 340   manol__9
# 341   y052009
# 342   Uilwz
# 343   MSalahM5
# 344   zt52v
# 345   iimayaxx
# 346   oRN5wQiyWqYkIum
# 347   1iAbrar
# 348   nojenes
# 349   Sahayib_R
# 350   yassba
# 351   m_x1c2c33
# 352   Gfjl6
# 353   Nds626
# 354   FADIA_6
# 355   oRN5wQiyWqYkIum
# 356   nejooomFm
# 357   Binkadeib
# 358   roon14637605
# 359   Monna46297870
# 360   toot52508919
# 361   a_ty276
# 362   F_H_4423
# 363   badr_alkhalid
# 364   purete95
# 365   FADIA_6
# 366   mh9fQwvpVC4BcXm
# 367   purete95
# 368   sarah19372344
# 369   wajdnz_23
# 370   noone40744954
# 371   Alnaseej
# 372   qwxx55
# 373   newlifehayat
# 374   oRN5wQiyWqYkIum
# 375   Gaemhera
# 376   noona75010071
# 377   Hr_arwa_
# 378   tehyb_alhrbi
# 379   memsh5311
# 380   AnfalQ
# 381   9Iau11Ekyt6f005
# 382   rushdi9
# 383   alwahdani7
# 384   meshal1147
# 385   omega_boy96
# 386   xmanilla8
# 387   dD4C5p7JaMy0wz8
# 388   toot52508919
# 389   nykosh5
# 390   abdulazizaltur2
# 391   0nkal
# 392   monima268
# 393   Sma199911
# 394   Sma199911
# 395   alfoz89790790
# 396   nader_418
# 397   wajdnz_23
# 398   Ayman_A_Badr
# 399   Ayman_A_Badr
# 400   Ayman_A_Badr
# 401   s0Hpz787iccnbw9
# 402   Shaymaa57018768
# 403   Sahayib_R
# 404   7_hf0w
# 405   doctorent1
# 406   noofsal43517396
# 407   llkiu4
# 408   y1pd
# 409   99911Ff
# 410   xjon9a
# 411   xjon9a
# 412   zizooo3
# 413   ab198846
# 414   QB5xJKzEx0wbnTA
# 415   99911Ff
# 416   y__31_
# 417   RJR9I
# 418   aloshaa23
# 419   tahaanii5
# 420   sfzf84
# 421   maha_aljhani
# 422   ab198846
# 423   F2020N
# 424   Mansour_4m
# 425   mimon828
# 426   imadi012
# 427   Mohamme89942594
# 428   Lubna57270550
# 429   Digital___code
# 430   y__31_
# 431   shmoos_b
# 432   Ans50994757
# 433   JamaanAlsultan
# 434   Ans50994757
# 435   qeqaaa
# 436   QIKZQidjR0XoxWZ
# 437   jooj17436
# 438   mrydhkryat709
# 439   Rabah30937976
# 440   raai1212
# 441   MeeEm887
# 442   sh2o5sho
# 443   Aisaah8
# 444   SenoritArabica
# 445   S_abah2020
# 446   tahaanii5
# 447   mrydhkryat709
# 448   shmoos_b
# 449   reeem247848
# 450   Survival0_
# 451   QIKZQidjR0XoxWZ
# 452   WOOROODELFULL
# 453   Star__ksa
# 454   abogeyad
# 455   azoozabood48
# 456   iisomr
# 457   k_ali93
# 458   Q1_Q1O
# 459   Y__Asiri
# 460   9rFEUJGD1TLFSlF
# 461   abwaebdalllah11
# 462   o8ztl1rYQ6FDGiZ
# 463   aljabass
# 464   Bushra_iil
# 465   maxs889
# 466   Abod47314283
# 467   3778Talal
# 468   brv1i
# 469   sgh552
# 470   1evc55WhSo6iC0d
# 471   t13939409
# 472   Tall_700
# 473   04xIhkt550nwD4g
# 474   04xIhkt550nwD4g
# 475   q_q118
# 476   04xIhkt550nwD4g
# 477   04xIhkt550nwD4g
# 478   abbodd_19
# 479   KhokhaBk69
# 480   SWRzJp60Q7PrQK9
# 481   Dalaaal8
# 482   t13939409
# 483   ro3h012
# 484   aljabass
# 485   ta_t000
# 486   sirafat
# 487   lucky_meesh
# 488   9rFEUJGD1TLFSlF
# 489   aaqilah22
# 490   Ghiin_233
# 491   Bross199999
# 492   NasserAlfisaly
# 493   NasserAlfisaly
# 494   Bross199999
# 495   Bross199999
# 496   Bross199999
# 497   Ayouch601
# 498   shababii10
# 499   AljabalA
# 500   AljabalA
# 501   1992__77
# 502   EyVMXQdvsRhPoJ1
# 503   qorosh1
# 504   AljabalA
# 505   qorosh1
# 506   kD066
# 507   vr9VT5oTqZrPHv5
# 508   hus2028
# 509   SamGhallager
# 510   Hawraa109
# 511   Kingdeer7
# 512   Ghiin_233
# 513   46UQC
# 514   7R4A3
# 515   BSatm812
# 516   SOMAN87363276
# 517   ghalyahali
# 518   f_vlo1
# 519   s9kB2cEfYbXlgPW
# 520   mlam7an
# 521   Asz52754442
# 522   abcdedcba123451
# 523   vbilor
# 524   wa_ad77
# 525   nsns0007
# 526   J1gqH6UqxEYu2qa
# 527   AlomariAzzoza
# 528   k_ali93
# 529   ahlaalm
# 530   Dalaaal8
# 531   S_a8800
# 532   rambo_2030
# 533   r5_9
# 534   azoozabood48
# 535   lucky_meesh
# 536   almothalif20301
# 537   GannasAluyon
# 538   FA7hil
# 539   HaninAlghamdi2
# 540   sithsh_a
# 541   Mhl_otb
# 542   QahFO4BppX3RKMV
# 543   TZI1GoCDNCrkE2i
# 544   remah252
# 545   abeersfn
# 546   5Maya_Morad
# 547   h9JSiMd3Zw1dxHD
# 548   zooz511110
# 549   aljazi11225
# 550   meaad126722
# 551   meaad126722
# 552   ta_t000
# 553   Alii82155496
# 554   icspsy
# 555   arif__eid
# 556   vvxili
# 557   ghm707_1
# 558   HamadhHommad
# 559   sarasaud88
# 560   noonah232gmail1
# 561   ShathaSalhe
# 562   Da1ia17
# 563   xbbx2018
# 564   moghredh
# 565   emaad_h__
# 566   Saja07936296
# 567   dbLjGgUlmBNN2JT
# 568   galamusa12
# 569   besh_xo_
# 570   WOOROODELFULL
# 571   T9mi_
# 572   existingproof
# 573   wadha___sh
# 574   SaraALmofarajy
# 575   kangnil1
# 576   T9mi_
# 577   SaraALmofarajy
# 578   Naifb1414
# 579   AltaweelZainab
# 580   ghalalool
# 581   Mubher7
# 582   xx_iiiiiiiiii
# 583   hi_zen
# 584   minnni27
# 585   Can7lllm
# 586   Can7lllm
# 587   Mohammed__12
# 588   minnni27
# 589   Mubher7
# 590   sNxNqPn7cIMYaXV
# 591   hi_zen
# 592   ghai74
# 593   c53L7Tm5KuGwjbN
# 594   Can7lllm
# 595   hi_zen
# 596   pFbagYBjV9F3aN6
# 597   pFbagYBjV9F3aN6
# 598   64356031Nj
# 599   64356031Nj
# 600   64356031Nj
# 601   ghai74
# 602   shcvl2
# 603   onlyra93
# 604   myttaap
# 605   Mishmas45
# 606   esaaesaa16
# 607   shcvl2
# 608   __inoura3
# 609   myttaap
# 610   mo_ny4
# 611   aaksqh
# 612   retajf8
# 613   retajf8
# 614   retajf8
# 615   retajf8
# 616   retajf8
# 617   rxnm1_18
# 618   retajf8
# 619   rxnm1_18
# 620   retajf8
# 621   Hishtick
# 622   1joods
# 623   ali_mattash
# 624   khalid__107A
# 625   retajf8
# 626   7QSYZW1
# 627   am_interior
# 628   mlam7an
# 629   7QSYZW1
# 630   rag_t_g
# 631   saroooonh33
# 632   _YAR27
# 633   90liiil
# 634   7j_3i
# 635   tlcpGuhlAEMH02V
# 636   x_moon98
# 637   Randali199
# 638   1_azz11
# 639   T13_art
# 640   jhh305
# 641   jhh305
# 642   abwaebdalllah11
# 643   moaid20201
# 644   jamalalmassa
# 645   Raham1123
# 646   moaid20201
# 647   h_n_hn
# 648   xrn95
# 649   Haiat101
# 650   xrn95
# 651   ilx0n7su9yJg8lx
# 652   Ni0iq
# 653   xrn95
# 654   esaaesaa16
# 655   kyNX1gBBR53hUsN
# 656   yNDSSHWos5QaRpH
# 657   kyNX1gBBR53hUsN
# 658   D8DE7OugS549pMU
# 659   D8DE7OugS549pMU
# 660   D8DE7OugS549pMU
# 661   DouhaH2
# 662   bntbaddal
# 663   bntbaddal
# 664   t13939409
# 665   jo_joma11
# 666   jejo879
# 667   rem_mer6
# 668   alrmelh8
# 669   ms_s955
# 670   kholood7715
# 671   rem_mer6
# 672   _3358388341541
# 673   Mary61514490
# 674   AlmeteryMeral
# 675   hana66361888
# 676   t13939409
# 677   mllllv
# 678   faljubairi
# 679   AlmeteryMeral
# 680   rerrta
# 681   8iil9_
# 682   rerrta
# 683   8iil9_
# 684   MAHMOUDBAKER3
# 685   Maryam20910
# 686   mimo7_26
# 687   xbbx2018
# 688   rerrta
# 689   sh3Laa900
# 690   HananBkri
# 691   HananBkri
# 692   R45418434
# 693   Alreem9006
# 694   6man___
# 695   6man___
# 696   nxy92
# 697   nxy92
# 698   nxy92
# 699   feno1_Q
# 700   feno1_Q
# 701   mimo7_26
# 702   1lqaZQBeRD9ZpKQ
# 703   nii_iu
# 704   MAHMOUDBAKER3
# 705   dbLjGgUlmBNN2JT
# 706   XRd_Hfc
# 707   daan__07
# 708   qq111rr
# 709   nii_iu
# 710   nxy92
# 711   feno1_Q
# 712   nxy92
# 713   Saja07936296
# 714   KvoE5rFy6EbGYHx
# 715   jobsy_12
# 716   AHEDHKMY
# 717   MADRIDE_8
# 718   AHEDHKMY
# 719   MADRIDE_8
# 720   Turki_3D
# 721   MADRIDE_8
# 722   431salleh
# 723   jo_joma11
# 724   jobsy_12
# 725   t_iiv1
# 726   AboreemaM
# 727   hana66361888
# 728   Amool152495622
# 729   D8DE7OugS549pMU
# 730   q_q118
# 731   q_q118
# 732   feno1_Q
# 733   q_q118
# 734   zahraahr2
# 735   I_loay1
# 736   gAnS2zkDFrvhAK6
# 737   cordelia_96
# 738   Zozaali63165630
# 739   danih72611125
# 740   cordelia_96
# 741   ahlamhajlaa
# 742   iiqt88
# 743   xe_398
# 744   cordelia_96
# 745   2af_ni
# 746   5U47SdWPhTUP9Ma
# 747   ii_rr66
# 748   Hadeel_484
# 749   khookha97531
# 750   psx7_
# 751   ii_rr66
# 752   iiqt88
# 753   al__alway
# 754   nany1234571
# 755   noofz2000
# 756   al__alway
# 757   nxy92
# 758   nxy92
# 759   araf11231
# 760   SailhAsas
# 761   E1S1PvKVq4DWJRJ
# 762   f5r_3nzh
# 763   o6a__hanem
# 764   psx7_
# 765   BMWxCZ854jnd7Tu
# 766   u7GdjAvuwSABa9V
# 767   199Ndooy
# 768   she202020
# 769   0550389899
# 770   zinasaed2233
# 771   zinasaed2233
# 772   199Ndooy
# 773   danih72611125
# 774   YahyaYahyakaram
# 775   danih72611125
# 776   Nabilshaaaa
# 777   haya87154575
# 778   _JEJE1_
# 779   haya87154575
# 780   faljubairi
# 781   ql3YEb5qEMrzZJT
# 782   Bader4488
# 783   m11haii
# 784   Bader4488
# 785   lCvxQl4d6Ujkiz5
# 786   sa_h_ali
# 787   s404sa
# 788   s404sa
# 789   Sutz74DmMhbQO36
# 790   abomaya84207745
# 791   lCvxQl4d6Ujkiz5
# 792   lCvxQl4d6Ujkiz5
# 793   Sutz74DmMhbQO36
# 794   SABA__7
# 795   NoooorJeddah
# 796   wsife1
# 797   YahyaYahyakaram
# 798   KTixYXyjvY4THdm
# 799   PrdeeAl
# 800   abomaya84207745
# 801   LayaliAlmatar1
# 802   i_Abdulrahmanz
# 803   purozle
# 804   jafari48_ah
# 805   lvl_wp
# 806   MidnightStory12
# 807   sarasaud88
# 808   abomaya84207745
# 809   i_Abdulrahmanz
# 810   LayaliAlmatar1
# 811   jafari48_ah
# 812   _iL21l
# 813   jafari48_ah
# 814   emaad_h__
# 815   s9784370
# 816   mfaridsrour
# 817   _mfs_2
# 818   i_Abdulrahmanz
# 819   ialaa87
# 820   mr__zemo
# 821   MZN_91
# 822   artist1_
# 823   AtifObaid22
# 824   abofasl14
# 825   inspiration_zi
# 826   hibh12345678901
# 827   qq111rr
# 828   maybenot612
# 829   2011Noranasser
# 830   Sbk0aI
# 831   kholodesmail
# 832   Nouralhuda3
# 833   zxcv6801
# 834   Abod7Abod1122
# 835   khalid__107A
# 836   seen_83
# 837   goozza7
# 838   jzeert_abujmeel
# 839   fahdbinjaber
# 840   xzxzkhalid1
# 841   zxcv6801
# 842   l2lxv
# 843   r_angel8
# 844   _llxiil
# 845   x_t7i
# 846   Bntfahad19
# 847   Rthaaaath
# 848   om_hisham8
# 849   bsfa37
# 850   x_t7i
# 851   QRT_ScArY
# 852   ahad__qh
# 853   334m2
# 854   memix112
# 855   alamre_khalovh
# 856   neshan00
# 857   H29672702
# 858   fahadkr2
# 859   Alkhaial4
# 860   xrc_sh
# 861   IfayIf
# 862   hilaleeeeeeee
# 863   noff114
# 864   mohammed575
# 865   Osama_haa
# 866   fatmih72416721
# 867   miss_sheem
# 868   alamre_khalovh
# 869   Abod7Abod1122
# 870   cRigHXnoNc1kIjC
# 871   0Emyo
# 872   Osama_haa
# 873   R45418434
# 874   NNameesan
# 875   Whatever_94
# 876   Meaad369
# 877   fatmih72416721
# 878   Sad123eq
# 879   cRigHXnoNc1kIjC
# 880   afalsubei
# 881   akbarlaa
# 882   UEOb4X29UleenZJ
# 883   Rn_T22
# 884   Rn_T22
# 885   abo_3li_506
# 886   akbarlaa
# 887   mernanabood
# 888   k_alslam
# 889   r_angel8
# 890   72lvc
# 891   aaaa12210711
# 892   Mira_8k
# 893   sola_800
# 894   72lvc
# 895   03auuLPuiyUGmAe
# 896   davRer0cWrUcuRv
# 897   Izzy_boe
# 898   choi_siro
# 899   choi_siro
# 900   7ssumy
# 901   Ali2527Q
# 902   pander43207091
# 903   wSvUA0yab92e5VE
# 904   choi_siro
# 905   feno1_Q
# 906   smq61
# 907   feno1_Q
# 908   samar__897
# 909   wSvUA0yab92e5VE
# 910   feno1_Q
# 911   Naifha22121399
# 912   lucky_meesh
# 913   coool890
# 914   _oes0
# 915   Mhmd156m
# 916   our_dar
# 917   66MNaD4iGrxjzwV
# 918   hmode_323
# 919   sultan_d_sh
# 920   coool890
# 921   sultan_d_sh
# 922   atthadakum333
# 923   h_n_hn
# 924   hashimjadaan
# 925   NNHHMM8
# 926   mnifa16
# 927   lucky_meesh
# 928   Teacherahood
# 929   stronger4ever11
# 930   M6A9__
# 931   ll_nm335
# 932   Light1Dragon
# 933   hilaleeeeeeee
# 934   GenArara1
# 935   1_yj5
# 936   a_myas
# 937   mime29_1
# 938   mime29_1
# 939   aboleel8abolel5
# 940   Bader_M201
# 941   Bader_M201
# 942   aboleel8abolel5
# 943   nouf20777117
# 944   nouf20777117
# 945   m_o_79
# 946   w_68_
# 947   ibrahemkurdi20
# 948   rpqr711
# 949   w_68_
# 950   Afnan10343284
# 951   rpqr711
# 952   abo3le334
# 953   w_68_
# 954   w_68_
# 955   zozoSait
# 956   2Mutir
# 957   basmasaud12
# 958   i3ra7
# 959   Loveyellow
# 960   i3ra7
# 961   mawadahalmrs
# 962   MOGNHCUqmesp9VI
# 963   i__rain
# 964   Ashwaq___m
# 965   12Bandary01
# 966   i__rain
# 967   Ashwaq___m
# 968   saitama__dream
# 969   t_TAAROK
# 970   llil2li
# 971   t_TAAROK
# 972   t_TAAROK
# 973   t_TAAROK
# 974   a_rrrsss
# 975   aishabdull
# 976   t_TAAROK
# 977   78__ii
# 978   oo_4r
# 979   oo_4r
# 980   gh_kenizy
# 981   roo7_fr7
# 982   a4_h1y1
# 983   Sbk0aI
# 984   QRNAS_7
# 985   zozoSait
# 986   Sbk0aI
# 987   7MncBpUSV0HK0KQ
# 988   7MncBpUSV0HK0KQ
# 989   alsubaiekhalid
# 990   alsubaiekhalid
# 991   KhalidmegM
# 992   KhalidmegM
# 993   Av1S6n
# 994   h_1437_
# 995   alburaai
# 996   Faisal_Alzu
# 997   mokkahal
# 998   TNAm4AUAPJpbGD6
# 999   TNAm4AUAPJpbGD6
# 1000  TNAm4AUAPJpbGD6
# 1001  TNAm4AUAPJpbGD6
# 1002  aesOWc7BFyfVRVr
# 1003  aesOWc7BFyfVRVr
# 1004  aesOWc7BFyfVRVr
# 1005  aesOWc7BFyfVRVr
# 1006  mhb15577
# 1007  Abdullah_5452
# 1008  sayelnosir
# 1009  sulaiman_hfc
# 1010  omaralhashemi2
# 1011  wiooir
# 1012  alhamdankhalida
# 1013  mHatHut
# 1014  ALIWOLFX
# 1015  F1oki_
# 1016  hjoo_mosaa
# 1017  4L0Uelg11jWIIC8
# 1018  dodico0ol
# 1019  C0Tr0
# 1020  AldreesSaud
# 1021  Abood71112555
# 1022  AldreesSaud
# 1023  AldreesSaud
# 1024  Albrady6
# 1025  feyafi_
# 1026  Abood71112555
# 1027  htJCpkx0fg0jjul
# 1028  Abood71112555
# 1029  mutab_8
# 1030  alshaddadi2
# 1031  alshaddadi2
# 1032  abosma1426
# 1033  htJCpkx0fg0jjul
# 1034  Albrady6
# 1035  Free_Registry9
# 1036  angel5boom
# 1037  solarnewm
# 1038  almore2030
# 1039  Ash63720077
# 1040  ksaeedi2
# 1041  ZafraQuhtany
# 1042  ALfadni95
# 1043  abobasil11
# 1044  ABDULR7MAN___
# 1045  PStationFanboy
# 1046  PStationFanboy
# 1047  gods_mistake0
# 1048  AL20308
# 1049  yyyy56688
# 1050  yyyy56688
# 1051  yyyy56688
# 1052  AL20308
# 1053  AL20308
# 1054  mansorz8
# 1055  mansorz8
# 1056  AL20308
# 1057  ENAHMD0102
# 1058  akbarlaa
# 1059  ENAHMD0102
# 1060  hammod335
# 1061  modeer_mnsbh
# 1062  faris19m
# 1063  mo7amd807
# 1064  ABDULR7MAN___
# 1065  d7ooomy_177
# 1066  haveMercy000
# 1067  samnan5566
# 1068  harthimr1
# 1069  smokrak
# 1676  Starsforlive
# 1677  hh6688900
# 1678  AwnLeya
# 1679  alwaseemj
# 1680  o_i_9
# 1681  SALEH_33557
# 1682  SALEH_33557
# 1683  almhryb1
# 1684  yousefabdalazi1
# 1685  Laseliastore
# 1686  SZuFqXB27YcZLBR
# 1687  nan3917
# 1688  3zBinSalman
# 1689  3zBinSalman
# 1690  asrarjun
# 1691  Qp9XiUutf6uYGpf
# 1692  abonomai2
# 1693  Qp9XiUutf6uYGpf
# 1694  ONECUP_SA
# 1695  h9e2
# 1696  Khado0oj_44
# 1697  Mohamed92226110
# 1698  Mohamed92226110
# 1699  Mohamed92226110
# 1700  focomu1
# 1701  eqab_alzaamil
# 1702  J7K77
# 1703  salehmood13
# 1704  fg4566789
# 1705  fg4566789
# 1706  OmirSwan
# 1707  eqab_alzaamil
# 1708  abdullahm_z31
# 1709  salll_m
# 1710  mshia_15
# 1711  khaled3yf
# 1712  Fahd85757594
# 1713  5PKTG6apCnfggrS
# 1714  GadeerGadeer16
# 1715  alfahaad12
# 1716  MBS_NEWS_
# 1717  sae29053372
# 1718  MagidA09
# 1719  Mary61514490
# 1720  Alkhmshe_badr
# 1721  meSH___23
# 1722  bushraalomar
# 1723  TurkyAljaloud
# 1724  1byMjzBZyDpgEU3
# 1725  1byMjzBZyDpgEU3
# 1726  SaudSaad1777777
# 1727  1byMjzBZyDpgEU3
# 1728  use_code_YjY
# 1729  uIc4lMpAJKHnpjG
# 1730  3Shmou5
# 1731  nouf20777117
# 1732  hmode__85
# 1733  Japal3709A
# 1734  GVEDyooAQi5jm80
# 1735  PmKtc1NGkNsymvs
# 1736  nJkEPW6gtLj3Fhi
# 1737  rozana_45
# 1738  abdullahm_z31
# 1739  NSweet06
# 1740  sosfaith
# 1741  aboleel5
# 1742  atlalnor
# 1743  prof4design
# 1744  took16059401
# 1745  took16059401
# 1746  hm5833
# 1747  ooocc6
# 1748  AyFuFRHWNaRCsSX
# 1749  tw1eet
# 1750  97marwan22
# 1751  97marwan22
# 1752  97marwan22
# 1753  Zx4839
# 1754  trad_ramz
# 1755  WXVX8WxWchEvdih
# 1756  trad_ramz
# 1757  Looz83
# 1758  mo3adalh
# 1759  trad_ramz
# 1760  ManelAhmed11
# 1761  3vvZy315Be4nq1p
# 1762  Faris27961977
# 1763  refa086
# 1764  44Ahmeedd
# 1765  0t25x
#
#                                                                                                                                                           text  \
# 0     [بنفسجي]
# 1     [ياثقل, طينته]
# 2     [الأحمر]
# 3     [لايضحكون, عليك, النفسيات, بالخزعبلات]
# 4     [سماوي, واسود]
# 5     [أحب, أهن, ي, الي, خلاك, تمسك, الحساب, وأقوله, إختيارك, أخضر]
# 6     [اله, يوفقكم]
# 7     [اعلم, هذا, بس, ليش, مايصير, لكم, الصلاحية, الجودة, و, توفير, الطاقة]
# 8     [السلام, عليكم, ابي, فزعتكم, لي, ياهل, الخير, انا, سجين, في, دين, وعندي, بزران, تضرومن, سجني, لامصرف, ولاي, شيء, حتى, المدا]
# 9     [تو, شرينا, غساله, ز, والمصري, يقول, ماتسحب, كهرباء, ابد, تعادل, خمس, نجوم]
