# %%
import nltk
nltk.download('punkt')
import numpy as np
import pandas as pd
import codecs
from nltk.corpus import stopwords
import numpy as np
import pandas as pd
import re
import csv
import string
from datetime import datetime
from collections import Counter
from nltk.tokenize import TweetTokenizer
from nltk.tokenize import   RegexpTokenizer
from nltk.tokenize import sent_tokenize, word_tokenize
# --------------------------------------- #
import pyarabic.araby as araby
import pyarabic.number as number
from pyarabic.araby import strip_tashkeel
from pyarabic.araby import strip_tatweel
from pyarabic.araby import tokenize, is_arabicrange, strip_tashkeel
# --------------------------------------- #
import pyarabic.arabrepr
arepr = pyarabic.arabrepr.ArabicRepr()
repr = arepr.repr
from tashaphyne.stemming import ArabicLightStemmer
import emoji



import seaborn
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# load dataset
df = pd.read_csv('Dataset1.csv', names=['id','text'])
df
# df = pd.read_csv('/Users/nadaa/Desktop/Osama/final_one.csv')
# df1 = pd.read_csv('/Users/nadaa/Downloads/Negitive_ready_half-1.csv')
# df2 = pd.read_csv('/Users/nadaa/Downloads/Neutral_ready_half.csv')
# df3 = pd.read_csv('/Users/nadaa/Downloads/Positive_ready_half.csv')
# Out:
#                      id                                               text
# 0   1358548548908892169  @AlkahrabaCare @MoEnergy_Saudi @SeecSaudi @Sau...
# 1   1358473139265679360  @AL_HAALEM @MoEnergy_Saudi @SeecSaudi @Saudi_A...
# 2   1358472484362854412  @AlkahrabaCare @MoEnergy_Saudi @SeecSaudi @Sau...
# 3   1358448238228037633  RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 4   1358444545428578313  RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 5   1358441355933016067  RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 6   1358427916191862787  RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 7   1358421752423022601  RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 8   1358419215464693762  RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 9   1358398934243307520  @taqa_sa محطة توليد كهرباء بالطاقة الشمسية قدر...
# 10  1358388185248788484  RT @taqa_sa: السيارة ما تحتاج أكثر من 30 ثانية...
# 11  1358325325290229761  @taqa_sa سؤالي هو ٢ ميقاوات تشغل كم مكيف فريون...
# 12  1358323716376170497  @taqa_sa 0563092288    للتنازل للتنازل\r\nجنسي...
# 13  1358317363809165312  RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 14  1358314375023652875    @taqa_sa طيب ياخي كيف اعرف سيارتي مافيها الملصق
# 15  1358314304802594826  RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 16  1358312918987735041  RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 17  1358312570164301824  RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 18  1358162908585287686  @AL_HAALEM @MoEnergy_Saudi @SeecSaudi @Saudi_A...
# 19  1358162082542321669  @AlkahrabaCare السلام عليكم اخي الكريم تم الاع...
# 20  1358075743067140096  RT @ELECTRIC__PRO: @taqa_sa حياكم الله .\r\n\r...
# 21  1358075640377995265  RT @ELECTRIC__PRO: @taqa_sa السخان العادي يسته...
# 22  1358075129268469764  RT @taqa_sa: السخان الفوري أفضل من السخان العا...
# 23  1358067517042876418  RT @aladdin2050: العلا ، و نيوم ،وبعض حديثٍ عن...
# 24  1357970890525409282  RT @aladdin2050: العلا ، و نيوم ،وبعض حديثٍ عن...
# 25  1357935592642908160  @Saudi_ECRA @taqa_sa شكرا .. اذا قصرتوا .. الا...
# 26  1357852751502467072  العلا ، و نيوم ،وبعض حديثٍ عن الطاقة. كلها أمو...
# 27  1357794433522089985  @innmr2 مرحبًا بك، نقدر اهتمامك بالترشيد ويمكن...
# 28  1357335700505460736  RT @taqa_sa: نصائح وسلوكيات بسيطة تساعدك بالتو...
# 29  1356893463900487681  RT @taqa_sa: ودكم توفّرون أكثر من 2000 ريال من...
# 30  1356484179727417345    @taqa_sa السلام عليكم\r\nايش افضل نوع سخان فوري
# 31  1356251080699604992  RT @taqa_sa: السيارة ما تحتاج أكثر من 30 ثانية...
# 32  1356235369424019456  @taqa_sa 30ثانية تختلف من مركبة لأخرى سيارتي م...
# 33  1356230704447819777  @taqa_sa حتى لمبة الحرارة الزرقاء ماتطفى بعد 3...
# 34  1356227816736649217  RT @taqa_sa: السيارة ما تحتاج أكثر من 30 ثانية...
# 35  1356226983265529860                         @taqa_sa ياليت تشرحون اكثر
# 36  1356226522588319746  RT @taqa_sa: السيارة ما تحتاج أكثر من 30 ثانية...
# 37  1356226282607009794                            @taqa_sa هل من شرح أكثر
# 38  1356226136460681216  RT @taqa_sa: السيارة ما تحتاج أكثر من 30 ثانية...
# 39  1356225956688621568  RT @taqa_sa: السيارة ما تحتاج أكثر من 30 ثانية...
# 40  1356225883179282433  RT @taqa_sa: السيارة ما تحتاج أكثر من 30 ثانية...
# 41  1355833336787308546                               @taqa_sa شكراً لكم 🙏
# 42  1355777182753292289  @taqa_sa السلام عليكم اريد اشتري لي جهاز كهربا...
# 43  1355497907244441602  @HashKSA @taqa_sa اقول متا ينزل البنزين ونرتاح...
# 44  1355384192553668615  @taqa_sa تكفون ادعموني ب لايك او رتويت الله ير...

# %%
# new = df.copy()
# new2 = df1.copy()
# new3 = df2.copy()
# new4 = df3.copy()

# new1 = new[['screen_name','text','sentiment']]
# nnew1 = new2[['screen_name','text','sentiment']]
# neew1 = new3[['screen_name','text','sentiment']]
# neww1 = new4[['screen_name','text','sentiment']]

# merged_df = pd.concat([nnew1, neew1])
# merged_df1 = pd.concat([neww1, merged_df])
# data = pd.concat([new1, merged_df1])

# data.head()
# Out:
#        screen_name                                               text  \
# 0      M_World2020  RT @M_World2020: https://t.co/nyyt4s0bsG\n#بلا...
# 1  B7Kgsvd72R2jzNL  RT @taqa_sa: جمعنا لكم أهم النصائح للتقليل من ...
# 2        Abohedab1  RT @taqa_sa: الجار قبل الدار والأخضر قبل الأحم...
# 3   Hanoma29441020  RT @taqa_sa: جمعنا لكم أهم النصائح للتقليل من ...
# 4      560Mohammad  RT @M_World2020: https://t.co/nyyt4s0bsG\n#بلا...
#
#   sentiment
# 0  Negative
# 1  Positive
# 2  Positive
# 3  Positive
# 4  Negative

# %%
# Reset the index of dataframe
newdata = df.reset_index()
newdata["id"] = newdata.id

newdata
# Out:
#     index                   id  \
# 0       0  1358548548908892169
# 1       1  1358473139265679360
# 2       2  1358472484362854412
# 3       3  1358448238228037633
# 4       4  1358444545428578313
# 5       5  1358441355933016067
# 6       6  1358427916191862787
# 7       7  1358421752423022601
# 8       8  1358419215464693762
# 9       9  1358398934243307520
# 10     10  1358388185248788484
# 11     11  1358325325290229761
# 12     12  1358323716376170497
# 13     13  1358317363809165312
# 14     14  1358314375023652875
# 15     15  1358314304802594826
# 16     16  1358312918987735041
# 17     17  1358312570164301824
# 18     18  1358162908585287686
# 19     19  1358162082542321669
# 20     20  1358075743067140096
# 21     21  1358075640377995265
# 22     22  1358075129268469764
# 23     23  1358067517042876418
# 24     24  1357970890525409282
# 25     25  1357935592642908160
# 26     26  1357852751502467072
# 27     27  1357794433522089985
# 28     28  1357335700505460736
# 29     29  1356893463900487681
# 30     30  1356484179727417345
# 31     31  1356251080699604992
# 32     32  1356235369424019456
# 33     33  1356230704447819777
# 34     34  1356227816736649217
# 35     35  1356226983265529860
# 36     36  1356226522588319746
# 37     37  1356226282607009794
# 38     38  1356226136460681216
# 39     39  1356225956688621568
# 40     40  1356225883179282433
# 41     41  1355833336787308546
# 42     42  1355777182753292289
# 43     43  1355497907244441602
# 44     44  1355384192553668615
#
#                                                  text
# 0   @AlkahrabaCare @MoEnergy_Saudi @SeecSaudi @Sau...
# 1   @AL_HAALEM @MoEnergy_Saudi @SeecSaudi @Saudi_A...
# 2   @AlkahrabaCare @MoEnergy_Saudi @SeecSaudi @Sau...
# 3   RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 4   RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 5   RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 6   RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 7   RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 8   RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 9   @taqa_sa محطة توليد كهرباء بالطاقة الشمسية قدر...
# 10  RT @taqa_sa: السيارة ما تحتاج أكثر من 30 ثانية...
# 11  @taqa_sa سؤالي هو ٢ ميقاوات تشغل كم مكيف فريون...
# 12  @taqa_sa 0563092288    للتنازل للتنازل\r\nجنسي...
# 13  RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 14    @taqa_sa طيب ياخي كيف اعرف سيارتي مافيها الملصق
# 15  RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 16  RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 17  RT @taqa_sa: اختيارك للسيارة على المستوى الأخض...
# 18  @AL_HAALEM @MoEnergy_Saudi @SeecSaudi @Saudi_A...
# 19  @AlkahrabaCare السلام عليكم اخي الكريم تم الاع...
# 20  RT @ELECTRIC__PRO: @taqa_sa حياكم الله .\r\n\r...
# 21  RT @ELECTRIC__PRO: @taqa_sa السخان العادي يسته...
# 22  RT @taqa_sa: السخان الفوري أفضل من السخان العا...
# 23  RT @aladdin2050: العلا ، و نيوم ،وبعض حديثٍ عن...
# 24  RT @aladdin2050: العلا ، و نيوم ،وبعض حديثٍ عن...
# 25  @Saudi_ECRA @taqa_sa شكرا .. اذا قصرتوا .. الا...
# 26  العلا ، و نيوم ،وبعض حديثٍ عن الطاقة. كلها أمو...
# 27  @innmr2 مرحبًا بك، نقدر اهتمامك بالترشيد ويمكن...
# 28  RT @taqa_sa: نصائح وسلوكيات بسيطة تساعدك بالتو...
# 29  RT @taqa_sa: ودكم توفّرون أكثر من 2000 ريال من...
# 30    @taqa_sa السلام عليكم\r\nايش افضل نوع سخان فوري
# 31  RT @taqa_sa: السيارة ما تحتاج أكثر من 30 ثانية...
# 32  @taqa_sa 30ثانية تختلف من مركبة لأخرى سيارتي م...
# 33  @taqa_sa حتى لمبة الحرارة الزرقاء ماتطفى بعد 3...
# 34  RT @taqa_sa: السيارة ما تحتاج أكثر من 30 ثانية...
# 35                         @taqa_sa ياليت تشرحون اكثر
# 36  RT @taqa_sa: السيارة ما تحتاج أكثر من 30 ثانية...
# 37                            @taqa_sa هل من شرح أكثر
# 38  RT @taqa_sa: السيارة ما تحتاج أكثر من 30 ثانية...
# 39  RT @taqa_sa: السيارة ما تحتاج أكثر من 30 ثانية...
# 40  RT @taqa_sa: السيارة ما تحتاج أكثر من 30 ثانية...
# 41                               @taqa_sa شكراً لكم 🙏
# 42  @taqa_sa السلام عليكم اريد اشتري لي جهاز كهربا...
# 43  @HashKSA @taqa_sa اقول متا ينزل البنزين ونرتاح...
# 44  @taqa_sa تكفون ادعموني ب لايك او رتويت الله ير...

# %%
arabic_punctuations = '''`÷×؛<>_()*&^%][ـ،/:"؟.,'{}~¦+|!”…“–ـ'''
english_punctuations = string.punctuation
punctuations_list = arabic_punctuations + english_punctuations
arabic_diacritics = re.compile("""
                             ّ    | # Tashdid
                             َ    | # Fatha
                             ً    | # Tanwin Fath
                             ُ    | # Damma
                             ٌ    | # Tanwin Damm
                             ِ    | # Kasra
                             ٍ    | # Tanwin Kasr
                             ْ    | # Sukun
                             ـ     # Tatwil/Kashida
                         """, re.VERBOSE)


def normalize_arabic(text):
    text = re.sub("[إأآا]", "ا", text)
    text = re.sub("ى", "ي", text)
    text = re.sub("ؤ", "ء", text)
    text = re.sub("ئ", "ء", text)
    text = re.sub("ة", "ه", text)
    text = re.sub("گ", "ك", text)
    return text

# def space(text):
#     text= re.sub(r"_", '\s+', s)
#     return text

# new1['text'].replace('_', ' ', regex=True, inplace=True)


def remove_diacritics(text):
    text = re.sub(arabic_diacritics, '', text)
    return text


def remove_punctuations(text):
    translator = str.maketrans('', '', punctuations_list)
    return text.translate(translator)


def remove_repeating_char(text):
    return re.sub(r'(.)\1+', r'\1', text)

def remove_hashtag(text):
    return text.replace("#\\p{IsAlphabetic}+", "");

# %%
def processPost(tweet):

    #Replace @username with empty string
    tweet = re.sub('@[^\s]+', ' ', tweet)
    
    #Replace RT with empty string
    tweet = re.sub('RT', ' ', tweet)
    
    #Convert www.* or https?://* to " "
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))',' ',tweet)
    
    #Replace #word with word
    tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
    
    
    #remove non-arabic
#      tweet = re.sub(r'[^ء-ي0-9]',' ',tweet)

    return tweet

# %%
newdata['text'].replace('[^ء-ي0-9]', ' ', regex=True, inplace=True)

newdata['text'].replace('_', ' ', regex=True, inplace=True)

newdata['text'] = newdata['text'].str.replace(r'\d+','')

newdata['text']= newdata['text'].apply(lambda x: remove_diacritics(x))

newdata['text']= newdata['text'].apply(lambda x: remove_repeating_char(x))

newdata['text']= newdata['text'].apply(lambda x: processPost(x))

newdata['text']= newdata['text'].apply(lambda x: remove_hashtag(x))

newdata['text']= newdata['text'].apply(lambda x: remove_punctuations(x))

newdata['text']= newdata['text'].apply(lambda x: remove_repeating_char(x))
# Out:
# <ipython-input-7-643c676eab42>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   newdata['text'] = newdata['text'].str.replace(r'\d+','')

# %%
tokens = TweetTokenizer()
newdata['text'] = newdata['text'].apply(tokens.tokenize)

newdata.head(10)
# Out:
#    index                   id  \
# 0      0  1358548548908892169
# 1      1  1358473139265679360
# 2      2  1358472484362854412
# 3      3  1358448238228037633
# 4      4  1358444545428578313
# 5      5  1358441355933016067
# 6      6  1358427916191862787
# 7      7  1358421752423022601
# 8      8  1358419215464693762
# 9      9  1358398934243307520
#
#                                                 text
# 0                                           [اشكركم]
# 1              [أخي, العزيز, أبوسعود, تم, الرد, على]
# 2                     [تم, فتح, تم, إغلاق, مكن, اعر]
# 3  [اختيارك, لسيارة, على, المستوى, الأخضر, في, بط...
# 4  [اختيارك, لسيارة, على, المستوى, الأخضر, في, بط...
# 5  [اختيارك, لسيارة, على, المستوى, الأخضر, في, بط...
# 6  [اختيارك, لسيارة, على, المستوى, الأخضر, في, بط...
# 7  [اختيارك, لسيارة, على, المستوى, الأخضر, في, بط...
# 8  [اختيارك, لسيارة, على, المستوى, الأخضر, في, بط...
# 9  [محطة, توليد, كهرباء, بالطاقة, الشمسية, قدرتها...

# %%
stop = ['إذ', 'إذا', 'إذما', 'إذن', 'أف', 'أقل', 'أكثر', 'ألا', 'إلا', 'التي', 'الذي', 'الذين', 'اللاتي', 'اللائي', 'اللتان', 'اللتيا', 'اللتين', 'اللذان', 'اللذين', 'اللواتي', 'إلى', 'إليك', 'إليكم', 'إليكما', 'إليكن', 'أم', 'أما', 'أما', 'إما', 'أن', 'إن', 'إنا', 'أنا', 'أنت', 'أنتم', 'أنتما', 'أنتن', 'إنما', 'إنه', 'أنى', 'أنى', 'آه', 'آها', 'أو', 'أولاء', 'أولئك', 'أوه', 'آي', 'أي', 'أيها', 'إي', 'أين', 'أين', 'أينما', 'إيه', 'بخ', 'بس', 'بعد', 'بعض', 'بك', 'بكم', 'بكم', 'بكما', 'بكن', 'بل', 'بلى', 'بما', 'بماذا', 'بمن', 'بنا', 'به', 'بها', 'بهم', 'بهما', 'بهن', 'بي', 'بين','و', 'بيد',
         'تلك', 'تلكم', 'تلكما', 'ته', 'تي', 'تين', 'تينك',
         'ثم', 'ثمة', 'حاشا', 'حبذا', 'حتى', 'حيث', 'حيثما',
         'حين', 'خلا', 'دون', 'ذا', 'ذات', 'ذاك', 'ذان', 'ذانك', 'ذلك',
         'ذلكم', 'ذلكما', 'ذلكن', 'ذه', 'ذو', 'ذوا', 'ذواتا',
         'ذواتي', 'ذي', 'ذين', 'ذينك', 'ريث', 'سوف', 'سوى', 'شتان', 'عدا',
         'عسى', 'عل', 'على', 'عليك', 'عليه', 'عما', 'عن', 'عند', 'غير',
         'فإذا', 'فإن', 'فلا', 'فمن', 'في', 'فيم', 'فيما', 'فيه', 'فيها',
         'قد', 'كأن', 'كأنما', 'كأي', 'كأين', 'كذا', 'كذلك', 'كل', 'كلا',
         'كلاهما', 'كلتا', 'كلما', 'كليكما', 'كليهما', 'كم', 'كم', 'كما',
         'كي', 'كيت', 'كيف', 'كيفما', 'لا', 'لاسيما', 'لدى', 'لست', 'لستم',
         'لستما', 'لستن', 'لسن', 'لسنا', 'لعل', 'لك', 'لكم', 'لكما',
         'لكن', 'لكنما', 'لكي', 'لكيلا', 'لم', 'لما', 'لن', 'لنا',
         'له', 'لها', 'لهم', 'لهما', 'لهن', 'لو', 'لولا', 'لوما',
         'لي', 'لئن', 'ليت', 'ليس', 'ليسا', 'ليست', 'ليستا', 'ليسوا', 'ما',
         'ماذا', 'متى', 'مذ', 'مع', 'مما', 'ممن', 'من', 'منه', 'منها', 'منذ',
         'مه', 'مهما', 'نحن', 'نحو', 'نعم', 'ها', 'هاتان', 'هاته', 'هاتي',
         'هاتين', 'هاك', 'هاهنا', 'هذا', 'هذان', 'هذه', 'هذي', 'هذين', 'هكذا',
         'هل', 'هلا', 'هم', 'هما', 'هن', 'هنا', 'هناك', 'هنالك', 'هو', 'هؤلاء',
         'هي', 'هيا', 'هيت', 'هيهات', 'والذي', 'والذين', 'وإذ', 'وإذا', 'وإن',
         'ولا', 'ولكن', 'ولو', 'وما', 'ومن', 'وهو', 'يا' , 'من' , 'على', 'الى','هما', 'مع', 'هذه', 'التي', 'كما ', 'ذلك ', 'لذا', 'عن', 'في','ان','كان','كانت','الى','قبل','أنه','تم'
        ,'وقال','قال','فى','وقد','قد','ولم','وذلك','ذلك','يكون','او','وهذه','وهي ','وبعد','وهذا','عندها','جدا','بأن','انه','الي']

# %%
newdata['text'] = [w for w in newdata['text'] if not w in stop]
newdata.head()
# Out:
#    index                   id  \
# 0      0  1358548548908892169
# 1      1  1358473139265679360
# 2      2  1358472484362854412
# 3      3  1358448238228037633
# 4      4  1358444545428578313
#
#                                                 text
# 0                                           [اشكركم]
# 1              [أخي, العزيز, أبوسعود, تم, الرد, على]
# 2                     [تم, فتح, تم, إغلاق, مكن, اعر]
# 3  [اختيارك, لسيارة, على, المستوى, الأخضر, في, بط...
# 4  [اختيارك, لسيارة, على, المستوى, الأخضر, في, بط...

# %%
# import matplotlib.pyplot as plt
# y = newdata['sentiment'].value_counts()
# x = ['Positive', 'Neutral', 'Negative']
# ig = plt.figure(figsize =(10, 7)) 
# plt.pie(y, labels = x) 
# # show plot 
# plt.show()

# %% [markdown]
# # Model

# %% [markdown]
# ### vectorizer

# %%
y = newdata['text'].apply(lambda x: ' '.join(x))
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(max_features=1500, min_df=5, max_df=0.7, stop_words=stop)
X = vectorizer.fit_transform(y).toarray()
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['وهي'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '

# %% [markdown]
# ### TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidfconverter = TfidfTransformer()
X = tfidfconverter.fit_transform(X).toarray()
# Y = newdata.sentiment

# %% [markdown]
# ### Split data to train and test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(X, test_size=0.2, random_state=0)

# %% [markdown]
# ### Build Model

# %% [markdown]
# # GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB 
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split

gnb = GaussianNB().fit(X_train, y_train) 
gnb_predictions = gnb.predict(X_test) 
  
# accuracy on X_test 
accuracy = gnb.score(X_test, y_test) 
print (accuracy)
  
# creating a confusion matrix 
cm = confusion_matrix(y_test, gnb_predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f23725763117> in <module>
#       3 from sklearn.model_selection import train_test_split
#       4
# ----> 5 gnb = GaussianNB().fit(X_train, y_train)
#       6 gnb_predictions = gnb.predict(X_test)
#       7
#
# NameError: name 'y_train' is not defined

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test,gnb_predictions))
print(classification_report(y_test,gnb_predictions))
print(accuracy_score(y_test, gnb_predictions))
# Out:
# [[ 799   34   29]
#  [ 799  429  113]
#  [ 299   72 1624]]
#               precision    recall  f1-score   support
#
#     Negative       0.42      0.93      0.58       862
#      Neutral       0.80      0.32      0.46      1341
#     Positive       0.92      0.81      0.86      1995
#
#     accuracy                           0.68      4198
#    macro avg       0.71      0.69      0.63      4198
# weighted avg       0.78      0.68      0.68      4198
#
# 0.6793711291090996

# %% [markdown]
# # Saving and Loading the Model

# %% [markdown]
# ### Save model

# %%
import pickle
with open('GaussianNB', 'wb') as picklefile:
    pickle.dump(gnb,picklefile)

# %% [markdown]
# ### Lode model

# %%
import pickle
with open('GaussianNB', 'rb') as training_model:
    taqa1 = pickle.load(training_model)

# %% [markdown]
# #### Test from file

# %%
newdata['predictions'] = taqa1.predict(X)
#Or newdata['predictions'] = pd.DataFrame(Predictions) - if Length of values does not match length of index
newdata.head()
# Out:
#    index      screen_name                                               text  \
# 0      0      M_World2020  [بلاك, فرايدي, شي, إن, جامعة, الحفر, عن, بعد, ...
# 1      1  B7Kgsvd72R2jzNL  [جمعنا, لكم, أهم, النصائح, لتقليل, من, استهلاك...
# 2      2        Abohedab1  [الجار, قبل, الدار, والأخضر, قبل, الأحمر, وفرت...
# 3      3   Hanoma29441020  [جمعنا, لكم, أهم, النصائح, لتقليل, من, استهلاك...
# 4      4      560Mohammad  [بلاك, فرايدي, شي, إن, جامعة, الحفر, عن, بعد, ...
#
#   sentiment  id predictions
# 0  Negative   0    Negative
# 1  Positive   1    Positive
# 2  Positive   2    Positive
# 3  Positive   3    Positive
# 4  Negative   4    Negative
